# %% [markdown]
# ## Neural Search on Tv Shows Data Using Jina AI

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import urllib.request
import requests
import os

# %%
from bs4 import BeautifulSoup
import urllib.request
import requests
import os

# for How i met your mother
def links():
    directory =  'http://transcripts.foreverdreaming.org/viewforum.php?f=177&start='
    urls= []

    for i in range(9):
        urls.append(directory + str(25*i))
    return urls
    
def scriptLinks():
    pages = links()
    parser = 'html.parser'
    baseURL = 'http://transcripts.foreverdreaming.org'

    scripts = []
    for page in pages:
        resp = urllib.request.urlopen(page)
        soup = BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))
        for link in soup.find_all('a', href=True):
            if '&t=' in link['href']:
                scripts.append(baseURL + link['href'][1:])
    
    return scripts

def retrieveScripts():
    scripts = scriptLinks()
    parser = 'html.parser'

    for scriptLink in scripts:
        resp = urllib.request.urlopen(scriptLink)
        soup = BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))
        episodeTitle = soup.find_all('h2')[0].get_text()
        if 'Online Store' in episodeTitle or 'Board Update' in episodeTitle:
            continretrieveScripts()e

        season = episodeTitle[:2]
        episodeNum = episodeTitle[3:5]
        if not os.path.exists('TV Shows/How-I-Met-Your-Mother/Season-' + season):
            os.mkdir('TV Shows/How-I-Met-Your-Mother/Season-' + season )
        path = 'TV Shows/How-I-Met-Your-Mother/Season-' + season + '/Episode-' + episodeNum +'-'+ episodeTitle[8
        :] + '.txt'
        with open(path,'w') as out:
            for p in soup.find_all('p')[1:len(soup.find_all('p'))-3]:
                out.write(p.get_text()+'\n')
                
retrieveScripts()

# %%
# for friends

def links():
    directory =  'http://transcripts.foreverdreaming.org/viewforum.php?f=845&start='
    urls= []

    for i in range(9):
        urls.append(directory + str(25*i))
    return urls
    
def scriptLinks():
    pages = links()
    parser = 'html.parser'
    baseURL = 'http://transcripts.foreverdreaming.org'

    scripts = []
    for page in pages:
        resp = urllib.request.urlopen(page)
        soup = BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))
        for link in soup.find_all('a', href=True):
            if '&t=' in link['href']:
                scripts.append(baseURL + link['href'][1:])
    
    return scripts

def retrieveScripts():
    scripts = scriptLinks()
    parser = 'html.parser'

    for scriptLink in scripts:
        resp = urllib.request.urlopen(scriptLink)
        soup = BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))
        episodeTitle = soup.find_all('h2')[0].get_text()
        if 'Online Store' in episodeTitle or 'Board Update' in episodeTitle:
            continue

        season = episodeTitle[:2]
        episodeNum = episodeTitle[3:5]
        if not os.path.exists('TV Shows/Friends/Season-' + season):
            os.mkdir('TV Shows/Friends/Season-' + season )
        path = 'TV Shows/Friends/Season-' + season + '/Episode-' + episodeNum +'-'+ episodeTitle[8:] + '.txt'
        with open(path,'w') as out:
            for p in soup.find_all('p')[1:len(soup.find_all('p'))-3]:
                out.write(p.get_text()+'\n')
retrieveScripts()

# %%
# for Two and Half Men

def links():
    directory =  'http://transcripts.foreverdreaming.org/viewforum.php?f=870&start='
    urls= []

    for i in range(9):
        urls.append(directory + str(25*i))
    return urls
    
def scriptLinks():
    pages = links()
    parser = 'html.parser'
    baseURL = 'http://transcripts.foreverdreaming.org'

    scripts = []
    for page in pages:
        resp = urllib.request.urlopen(page)
        soup = BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))
        for link in soup.find_all('a', href=True):
            if '&t=' in link['href']:
                scripts.append(baseURL + link['href'][1:])
    
    return scripts

def retrieveScripts():
    scripts = scriptLinks()
    parser = 'html.parser'

    for scriptLink in scripts:
        resp = urllib.request.urlopen(scriptLink)
        soup = BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))
        episodeTitle = soup.find_all('h2')[0].get_text()
        if 'Online Store' in episodeTitle or 'Board Update' in episodeTitle:
            continue

        season = episodeTitle[:2]
        episodeNum = episodeTitle[3:5]
        if not os.path.exists('TV Shows/Two-And-Half-Men/Season-' + season):
            os.mkdir('TV Shows/Two-And-Half-Men/Season-' + season )
        path = 'TV Shows/Two-And-Half-Men/Season-' + season + '/Episode-' + episodeNum +'-'+ episodeTitle[8:] + '.txt'
        with open(path,'w') as out:
            for p in soup.find_all('p')[1:len(soup.find_all('p'))-3]:
                out.write(p.get_text()+'\n')
retrieveScripts()

# %% [markdown]
# ## creating a dataframe from the text files containing data of dialoges,speaker,Season,Episode,TV Show

# %%
def dialogues(path):
    
    f=open(path,'r')

    l=[]
    li=f.readlines()
    for i,j in enumerate(li):
        if ':' in j:
            sp=j[:j.index(':')]
            new=j[j.index(':')+1:]
        else:
            sp=np.nan
            new=j
        a=(new[:-1],sp)
        l.append(a)
    s=pd.DataFrame(l)
    
    s.columns=['Text','Speaker']
    s.set_index('Text',inplace=True)
    
    return s

# %%
import os 
    

df=pd.DataFrame(columns=['Text','Speaker','Episode','Season','Show'])
shows=os.listdir('TV Shows')

for show in shows:
    seasons=os.listdir("TV Shows/" + show)
    for season in seasons:
        episodes = os.listdir("TV Shows/" + show+ "/" + season)
        for episode in episodes:
            text1=dialogues('TV Shows/'+ show  +'/' + season +'/'+ episode)
            
            show1=pd.DataFrame([show] * text1.shape[0])
            show1.index=text1.index
            season1=pd.DataFrame([season] * text1.shape[0])
            season1.index=text1.index
            episode1=pd.DataFrame([episode[:-4]] * text1.shape[0])
            episode1.index=text1.index
            temp_df=pd.concat([text1,episode1,season1,show1],axis=1)
            #temp_df.set_index('Text',inplace=True)
            temp_df.columns=['Speaker','Episode','Season','Show']
            df=pd.concat([df,temp_df],axis=0)
            #df.set_index('Text')
            
            
df.drop('Text',axis=1,inplace=True)

# %%
dialogues("TV Shows/Two-And-Half-Men/Season-06/Episode-02-Pie Hole, Herb.txt")
# Out:
#                                               Speaker
# Text
#  Jk2write                                      Editor
# Thanks, Mom.                                      NaN
# This is a perfect first job for him.              NaN
# First job?                                        NaN
# I think you're looking at                         NaN
# ...                                               ...
# I can't believe Grandma fired me.                 NaN
# Well, buddy, the labor market's                   NaN
# very competitive these days.                      NaN
# There's always somebody                           NaN
# brighter and better willing to work for less.     NaN
#
# [540 rows x 1 columns]

# %%
# a sample data
df.iloc[187225:].head(10)
# Out:
#                                                          Speaker  \
#  Uh Phoebe, can I see you for a second?                     Ross
#  Yeah!                                                    Phoebe
# (They both go out into the hall.)                            NaN
#  What’s going on?                                         Phoebe
#  Chandler’s gone again!                                     Ross
#  Oh my God! Why would you play hide and seek wi...        Phoebe
# (Ross just glares at her.)                                   NaN
#  The Movie Set, Joey is walking up to the direc...        [Scene
#  Aaron! You gotta let me go. The guy’s hammered!            Joey
#  I’m sorry Joey, as long as he’s here and he’s ...  The Director
#
#                                                                                               Episode  \
#  Uh Phoebe, can I see you for a second?             Episode-23-07x24 - The One With Chandler and M...
#  Yeah!                                              Episode-23-07x24 - The One With Chandler and M...
# (They both go out into the hall.)                   Episode-23-07x24 - The One With Chandler and M...
#  What’s going on?                                   Episode-23-07x24 - The One With Chandler and M...
#  Chandler’s gone again!                             Episode-23-07x24 - The One With Chandler and M...
#  Oh my God! Why would you play hide and seek wi...  Episode-23-07x24 - The One With Chandler and M...
# (Ross just glares at her.)                          Episode-23-07x24 - The One With Chandler and M...
#  The Movie Set, Joey is walking up to the direc...  Episode-23-07x24 - The One With Chandler and M...
#  Aaron! You gotta let me go. The guy’s hammered!    Episode-23-07x24 - The One With Chandler and M...
#  I’m sorry Joey, as long as he’s here and he’s ...  Episode-23-07x24 - The One With Chandler and M...
#
#                                                        Season     Show
#  Uh Phoebe, can I see you for a second?             Season-07  Friends
#  Yeah!                                              Season-07  Friends
# (They both go out into the hall.)                   Season-07  Friends
#  What’s going on?                                   Season-07  Friends
#  Chandler’s gone again!                             Season-07  Friends
#  Oh my God! Why would you play hide and seek wi...  Season-07  Friends
# (Ross just glares at her.)                          Season-07  Friends
#  The Movie Set, Joey is walking up to the direc...  Season-07  Friends
#  Aaron! You gotta let me go. The guy’s hammered!    Season-07  Friends
#  I’m sorry Joey, as long as he’s here and he’s ...  Season-07  Friends

# %%
df.shape
# Out:
# (202001, 4)

# %%
df.to_csv('final.csv')

# %%
sample=df[df['Episode']=="Episode-04-The Flavin' and the Mavin"]
sample
# Out:
#                                             Speaker  \
#  Jk2write                                    Editor
# [CHUCKLES]                                      NaN
# I really appreciate you getting up so early     NaN
# and driving me to work.                         NaN
# I owe you one. Heh.                             NaN
# ...                                             ...
# - And health insurance.                         NaN
# - A given. Can't believe you don't have it.     NaN
# - And a paid vacation.                          NaN
# - Hang on a second. There's only...             NaN
# Aah! Two weeks, two weeks, two weeks!           NaN
#
#                                                                           Episode  \
#  Jk2write                                    Episode-04-The Flavin' and the Mavin
# [CHUCKLES]                                   Episode-04-The Flavin' and the Mavin
# I really appreciate you getting up so early  Episode-04-The Flavin' and the Mavin
# and driving me to work.                      Episode-04-The Flavin' and the Mavin
# I owe you one. Heh.                          Episode-04-The Flavin' and the Mavin
# ...                                                                           ...
# - And health insurance.                      Episode-04-The Flavin' and the Mavin
# - A given. Can't believe you don't have it.  Episode-04-The Flavin' and the Mavin
# - And a paid vacation.                       Episode-04-The Flavin' and the Mavin
# - Hang on a second. There's only...          Episode-04-The Flavin' and the Mavin
# Aah! Two weeks, two weeks, two weeks!        Episode-04-The Flavin' and the Mavin
#
#                                                 Season              Show
#  Jk2write                                    Season-06  Two-And-Half-Men
# [CHUCKLES]                                   Season-06  Two-And-Half-Men
# I really appreciate you getting up so early  Season-06  Two-And-Half-Men
# and driving me to work.                      Season-06  Two-And-Half-Men
# I owe you one. Heh.                          Season-06  Two-And-Half-Men
# ...                                                ...               ...
# - And health insurance.                      Season-06  Two-And-Half-Men
# - A given. Can't believe you don't have it.  Season-06  Two-And-Half-Men
# - And a paid vacation.                       Season-06  Two-And-Half-Men
# - Hang on a second. There's only...          Season-06  Two-And-Half-Men
# Aah! Two weeks, two weeks, two weeks!        Season-06  Two-And-Half-Men
#
# [559 rows x 4 columns]

# %%
df[df['Episode']=='Episode-02-Pie Hole, Herb.txt']
# Out:
#                                               Speaker  \
#  Jk2write                                      Editor
# Thanks, Mom.                                      NaN
# This is a perfect first job for him.              NaN
# First job?                                        NaN
# I think you're looking at                         NaN
# ...                                               ...
# I can't believe Grandma fired me.                 NaN
# Well, buddy, the labor market's                   NaN
# very competitive these days.                      NaN
# There's always somebody                           NaN
# brighter and better willing to work for less.     NaN
#
#                                                                      Episode  \
#  Jk2write                                      Episode-02-Pie Hole, Herb.txt
# Thanks, Mom.                                   Episode-02-Pie Hole, Herb.txt
# This is a perfect first job for him.           Episode-02-Pie Hole, Herb.txt
# First job?                                     Episode-02-Pie Hole, Herb.txt
# I think you're looking at                      Episode-02-Pie Hole, Herb.txt
# ...                                                                      ...
# I can't believe Grandma fired me.              Episode-02-Pie Hole, Herb.txt
# Well, buddy, the labor market's                Episode-02-Pie Hole, Herb.txt
# very competitive these days.                   Episode-02-Pie Hole, Herb.txt
# There's always somebody                        Episode-02-Pie Hole, Herb.txt
# brighter and better willing to work for less.  Episode-02-Pie Hole, Herb.txt
#
#                                                   Season              Show
#  Jk2write                                      Season-06  Two-And-Half-Men
# Thanks, Mom.                                   Season-06  Two-And-Half-Men
# This is a perfect first job for him.           Season-06  Two-And-Half-Men
# First job?                                     Season-06  Two-And-Half-Men
# I think you're looking at                      Season-06  Two-And-Half-Men
# ...                                                  ...               ...
# I can't believe Grandma fired me.              Season-06  Two-And-Half-Men
# Well, buddy, the labor market's                Season-06  Two-And-Half-Men
# very competitive these days.                   Season-06  Two-And-Half-Men
# There's always somebody                        Season-06  Two-And-Half-Men
# brighter and better willing to work for less.  Season-06  Two-And-Half-Men
#
# [540 rows x 4 columns]

# %%
df.shape
# Out:
# (202001, 4)

# %%
df.shape
# Out:
# (130314, 4)

# %%
dialogues('TV Shows/how-i-met-your-mother/s7/How I Met Your Mother - 7x01 - The Best Man.720p HDTV.DIMENSION.en.srt')
# Out:
#                                                       0
# 0                           <i>Kids, if there's one</i>
# 1                      <i>big theme to this story--</i>
# 3                                   <i>and I swear,</i>
# 4                         <i>we're totally, almost,</i>
# 6                      <i>not really all that close</i>
# ...                                                 ...
# 1223                                              Okay.
# 1225                            Really? You're gonna go
# 1226                                     with that tie?
# 1228  == sync, corrected by <font color="#00ff00">el...
# 1230  <font color="#ffff00" size=14>www.tvsubtitles....
#
# [744 rows x 1 columns]

# %%
df1=pd.DataFrame({'a':[1,2,3,4],'b':[5,6,7,8]})
df1.append([7,8])
# Out:
#      a    b    0
# 0  1.0  5.0  NaN
# 1  2.0  6.0  NaN
# 2  3.0  7.0  NaN
# 3  4.0  8.0  NaN
# 0  NaN  NaN  7.0
# 1  NaN  NaN  8.0
